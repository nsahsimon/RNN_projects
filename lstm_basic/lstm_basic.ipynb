# %%
# Run this only when necessary
# Never ru this cell first
# !git config --global user.name "nsahsimon"
# !git config --global user.email "nsahsimonai01@gmail.com"
# !git add .
# !git commit -m "_"
# !git push origin

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/deep_learning_projects/RNN_projects
# Out:
# /content/drive/MyDrive/deep_learning_projects/RNN_projects
